# %%
import numpy as np
import matplotlib.pyplot as plt

from IPython.display import set_matplotlib_formats
set_matplotlib_formats('svg')
# Out:
# C:\Users\nikol\AppData\Local\Temp\ipykernel_18256\25077795.py:5: DeprecationWarning: `set_matplotlib_formats` is deprecated since IPython 7.23, directly use `matplotlib_inline.backend_inline.set_matplotlib_formats()`
#   set_matplotlib_formats('svg')

# %%
input_func = np.genfromtxt("results.csv", delimiter=',')
grid_x = np.linspace(0, 1, 101)
plt.plot(grid_x, input_func)
plt.savefig("solution.svg")
